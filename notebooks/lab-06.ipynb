# %%
import exiftool

file = '../data/lab06/DJI_20231103151343_0002_Zenmuse-L1-mission.JPG'
with exiftool.ExifToolHelper() as et:
    metadata = et.get_metadata(file)
    for d in metadata:
        for k, v in d.items():
            print(f"Dict: {k} = {v}")
# Out:
# Dict: SourceFile = ../data/lab06/DJI_20231103151343_0002_Zenmuse-L1-mission.JPG
# Dict: ExifTool:ExifToolVersion = 12.69
# Dict: ExifTool:Warning = [minor] Possibly incorrect maker notes offsets (fix by 1783?)
# Dict: File:FileName = DJI_20231103151343_0002_Zenmuse-L1-mission.JPG
# Dict: File:Directory = ../data/lab06
# Dict: File:FileSize = 8873926
# Dict: File:ZoneIdentifier = Exists
# Dict: File:FileModifyDate = 2023:11:06 13:08:01-08:00
# Dict: File:FileAccessDate = 2023:11:06 13:31:46-08:00
# Dict: File:FileCreateDate = 2023:11:03 16:13:42-07:00
# Dict: File:FilePermissions = 100666
# Dict: File:FileType = JPEG
# Dict: File:FileTypeExtension = JPG
# Dict: File:MIMEType = image/jpeg
# Dict: File:ExifByteOrder = II
# Dict: File:ImageWidth = 5472
# Dict: File:ImageHeight = 3648
# Dict: File:EncodingProcess = 0
# Dict: File:BitsPerSample = 8
# Dict: File:ColorComponents = 3
# Dict: File:YCbCrSubSampling = 2 1
# Dict: EXIF:ImageDescription = DCIM\DJI_202311031513_016_
# ...
